# %%
#=============================================================================
# CHALLENGE ENTREPRISE - RAPPORT URGENT COMPARATIF  DES 3 HOPITAUX DU POOL
#==============================================================================

# Declaration de toutes les variables necessaires pour les 3 hopitaux

Hopital_district_kinkala = {
    'buddget_trim_fcfa' : 12_500_000, 'consultation' : 1847, 'hospitalisations': 312, 'deces_hospitaliers' : 8,
'lits_totaux': 45, 'lits_occupes' : 41,'medecins_permanents': 3, 'population': 85_000 
}
CMS_de_vindza = {
    'buddget_trim_fcfa' : 6_800_000, 'consultation' : 923, 'hospitalisations': 87, 'deces_hospitaliers' : 2,
'lits_totaux': 20, 'lits_occupes' : 14,'medecins_permanents': 1, 'population': 42_000 
}
Hopital_de_kindamba = {
    'buddget_trim_fcfa' : 9_200_000, 'consultation' : 1234, 'hospitalisations': 201, 'deces_hospitaliers' : 11,
'lits_totaux': 35, 'lits_occupes' : 33,'medecins_permanents': 2, 'population': 67_000
}

# Calcule des KPis pour chaque hopital et arrondir à 2 decimal

# Pour l'hopital de kinkala
cout_moyen_par_patient_kinkala = round(Hopital_district_kinkala['buddget_trim_fcfa']/Hopital_district_kinkala['consultation'],2)
taux_occupation_kinkala = round(Hopital_district_kinkala['lits_occupes']/Hopital_district_kinkala['lits_totaux']*100,2)
densite_medicale_kinkala = round(Hopital_district_kinkala['medecins_permanents']/Hopital_district_kinkala['population']*1000,2)
taux_mortalite_kinkala = round(Hopital_district_kinkala['deces_hospitaliers']/Hopital_district_kinkala['hospitalisations']*100,2)

# Pour le CMS de Vindza
cout_moyen_par_patient_vindza = round(CMS_de_vindza['buddget_trim_fcfa']/CMS_de_vindza['consultation'],2)
taux_occupation_vindza = round(CMS_de_vindza['lits_occupes']/CMS_de_vindza['lits_totaux']*100,2)
densite_medicale_vindza = round(CMS_de_vindza['medecins_permanents']/CMS_de_vindza['population']*1000,2)
taux_mortalite_vindza= round(CMS_de_vindza['deces_hospitaliers']/CMS_de_vindza['hospitalisations']*100,2)

# Pour l'hopital de kindamba
cout_moyen_par_patient_kindamba = round(Hopital_de_kindamba['buddget_trim_fcfa']/Hopital_de_kindamba['consultation'],2)
taux_occupation_kindamba = round(Hopital_de_kindamba['lits_occupes']/Hopital_de_kindamba['lits_totaux']*100,2)
densite_medicale_kindamba = round(Hopital_de_kindamba['medecins_permanents']/Hopital_de_kindamba['population']*1000,2)
taux_mortalite_kindamba = round(Hopital_de_kindamba['deces_hospitaliers']/Hopital_de_kindamba['hospitalisations']*100,2)

# Determiner l'hopital en situation critique 

#if taux_mortalite_kinkala > 0.02 or densite_medicale_kinkala < 0.05:
#print('Hopital en situation critique')

#if taux_mortalite_vindza  > 0.02 or densite_medicale_vindza < 0.05:
# print('Hopital en situation critique')

#if taux_mortalite_kindamba > 0.02 or densite_medicale_kindamba < 0.05:
#print('Hopital en situation critique')

# Bonus : Calculer si le budget total des 3 hopitaux suffit pour passer a 5 medecins chacun
buget_total_3_hopitaux = Hopital_district_kinkala['buddget_trim_fcfa']+CMS_de_vindza['buddget_trim_fcfa']+Hopital_de_kindamba['buddget_trim_fcfa']
cout_medecin_trim = 1_200_000
# Calculons le cout pour 5 medecins pour les 3 hopitaux
cout_medecin_total = cout_medecin_trim*5*3

print('='*85)
print('CHALLENGE ENTREPRISE - RAPPORT URGENT COMPARATIF  DES 3 HOPITAUX DU POOL')
print('='*85)
print('HOPITAL DE KINKALA')
print(f'Cout moyen par patient : {cout_moyen_par_patient_kinkala} FCFA')
print(f'Taux occupation     :  {taux_occupation_kinkala} %')
print(f"Taux de mortalilite :  {taux_mortalite_kinkala} %     [Seuil alerte : > 2%]")
print(f"Densite             :  {densite_medicale_kinkala}     [Seuil alerte : < 0.05]")
if taux_mortalite_kinkala > 0.02 or densite_medicale_kinkala < 0.05:
    print('Hopital en situation critique')
print('-'*85)
print('CMS DE VINDZA')
print(f'Cout moyen par patient : {cout_moyen_par_patient_vindza} FCFA')
print(f'Taux occupation     :  {taux_occupation_vindza} %')
print(f"Taux de mortalilite :  {taux_mortalite_vindza} %     [Seuil alerte : > 2%]")
print(f"Densite             :  {densite_medicale_vindza}     [Seuil alerte : < 0.05]")
if taux_mortalite_vindza > 0.02 or densite_medicale_vindza< 0.05:
    print('Hopital en situation critique')
print('-'*85)
print('HOPITAL DE KINDAMBA ')
print(f'Cout moyen par patient : {cout_moyen_par_patient_kindamba} FCFA')
print(f'Taux occupation     :  {taux_occupation_kindamba} %')
print(f"Taux de mortalilite :  {taux_mortalite_kindamba} %     [Seuil alerte : > 2%]")
print(f"Densite             :  {densite_medicale_kindamba}     [Seuil alerte : < 0.05]")
if taux_mortalite_kindamba > 0.02 or densite_medicale_kindamba < 0.05:
    print('Hopital en situation critique')
print('-'*85)
print('ALERTE')
print('Les 3 hopitaux sont dans une sitution critique')
print('-'*85)
print('Bonus :')
print(f'Budget total des 3 hopitaux : {buget_total_3_hopitaux}  FCFA')
print(f'Cout medecin par trimestre  : {cout_medecin_trim} FCFA')
print(f"Si l'on passe a 5 medecins pour les 3 hopitaux le cout devient : {cout_medecin_total} FCFA")
print('Le budget total des 3 hopitaux sera insuffisant pour couvrir le recrutement de 5 medecins par hopital')
print("="*85)
# Out:
# ...
# CHALLENGE ENTREPRISE - RAPPORT URGENT COMPARATIF  DES 3 HOPITAUX DU POOL
# ...
# HOPITAL DE KINKALA
# Cout moyen par patient : 6767.73 FCFA
# Taux occupation     :  91.11 %
# Taux de mortalilite :  2.56 %     [Seuil alerte : > 2%]
# Densite             :  0.04     [Seuil alerte : < 0.05]
# Hopital en situation critique
# -------------------------------------------------------------------------------------
# CMS DE VINDZA
# Cout moyen par patient : 7367.28 FCFA
# Taux occupation     :  70.0 %
# Taux de mortalilite :  2.3 %     [Seuil alerte : > 2%]
# Densite             :  0.02     [Seuil alerte : < 0.05]
# Hopital en situation critique
# -------------------------------------------------------------------------------------
# HOPITAL DE KINDAMBA
# Cout moyen par patient : 7455.43 FCFA
# Taux occupation     :  94.29 %
# Taux de mortalilite :  5.47 %     [Seuil alerte : > 2%]
# Densite             :  0.03     [Seuil alerte : < 0.05]
# Hopital en situation critique
# ...
