# %%
total_suspects = 0
total_confirmes = 0
total_deces = 0
total_actifs = 0
zones_vertes = 0
zones_jaunes = 0
zones_oranges = 0
zones_rouges  = 0
nb_districts  = 9

for i in range(1, nb_districts +1):
    print('--- District', i,'---')
    nom_district = input ('Nom du district : ')
    suspects = int(input('Cas suspect :'))
    confirmes = int(input('Cas confirmes :'))
    deces = int(input('Deces   :'))

    cas_actis = confirmes - deces

    if confirmes > 0 :
        letalite = ( deces /confirmes)* 100
    else:
        letalite = 0

    if confirmes >= 10:
        alerte = 'ROUGE'
        zones_rouges = zones_rouges + 1
    elif confirmes >= 5:
        alerte = 'ORANGE'
        zones_oranges = zones_oranges + 1
    elif confirmes >= 2:
        alerte = 'JAUNE'
        zones_jaunes = zones_jaunes + 1
    else:
        alerte = 'VERT'
        zones_vertes = zones_vertes + 1
    
    total_suspects = total_suspects + suspects
    total_confirmes = total_confirmes + confirmes
    total_deces = total_deces + deces
    total_actifs = total_actifs + cas_actis

    print(' Alerte :', alerte)
    print(' Actifs :', cas_actis)
    print("  Letalite :", round(letalite, 1), "%" )
    print()

print ('====================================================================')
print(' RAPPORT NATIONAL MPOX 2025')
print ('====================================================================')
print ('Districts analyses :', nb_districts)
print('Total suspects      :', total_suspects)
print('Total comfirmes     :', total_confirmes)
print('Total deces         :', total_deces)
print('Total actifs        :', total_actifs)
print('Zones vertes        :', zones_vertes)
print('Zones JAUNES        :', zones_jaunes)
print('Zones ORANGES       :', zones_oranges)
print('Zones ROUGES        :',zones_rouges)
print('======================================================================')
# Out:
# --- District 1 ---
#  Alerte : ROUGE
#  Actifs : 12
#   Letalite : 0.0 %
#
# --- District 2 ---
#  Alerte : JAUNE
#  Actifs : 2
#   Letalite : 0.0 %
#
# --- District 3 ---
#  Alerte : JAUNE
#  Actifs : 3
#   Letalite : 0.0 %
#
# --- District 4 ---
#  Alerte : JAUNE
#  Actifs : 3
#   Letalite : 0.0 %
#
# --- District 5 ---
#  Alerte : VERT
#  Actifs : 1
#   Letalite : 0.0 %
#
# --- District 6 ---
#  Alerte : JAUNE
#  Actifs : 2
#   Letalite : 0.0 %
#
# --- District 7 ---
#  Alerte : VERT
#  Actifs : 1
#   Letalite : 0.0 %
#
# --- District 8 ---
#  Alerte : VERT
#  Actifs : 1
#   Letalite : 0.0 %
#
# --- District 9 ---
#  Alerte : VERT
#  Actifs : 1
#   Letalite : 0.0 %
#
# ====================================================================
#  RAPPORT NATIONAL MPOX 2025
# ====================================================================
# Districts analyses : 9
# Total suspects      : 27
# Total comfirmes     : 26
# Total deces         : 0
# Total actifs        : 26
# Zones vertes        : 4
# Zones JAUNES        : 4
# Zones ORANGES       : 0
# Zones ROUGES        : 1
# ======================================================================
